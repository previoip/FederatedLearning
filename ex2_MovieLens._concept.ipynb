# %%
from src.data_examples.ex2_data_loader import ExampleDataLoader
import tensorflow_datasets as tf_dataset

import pandas as pd

# %%
data_loader = ExampleDataLoader()
data_loader.download().load()

# %%
tf_dataset.as_dataframe(data_loader.df_ratings.take(10))
# Out:
#    bucketized_user_age    movie_genres movie_id  \
# 0                 45.0             [7]   b'357'
# 1                 25.0         [4, 14]   b'709'
# 2                 18.0             [4]   b'412'
# 3                 50.0          [5, 7]    b'56'
# 4                 50.0        [10, 16]   b'895'
# 5                 18.0         [7, 16]   b'325'
# 6                 18.0   [2, 3, 4, 12]    b'95'
# 7                 25.0      [0, 5, 14]    b'92'
# 8                 25.0             [4]   b'425'
# 9                 25.0  [0, 1, 15, 18]   b'271'
#
#                                  movie_title  raw_user_age  timestamp  \
# 0  b"One Flew Over the Cuckoo's Nest (1975)"          46.0  879024327
# 1                b'Strictly Ballroom (1992)'          32.0  875654590
# 2             b'Very Brady Sequel, A (1996)'          24.0  882075110
# 3                     b'Pulp Fiction (1994)'          50.0  883326919
# 4                         b'Scream 2 (1997)'          55.0  891409199
# ...
